# %% [markdown]
# The `yolo11.yaml` configuration file has been modified to optimize the YOLO11n model for detecting shrimp fry. The changes include:
#
# - Setting `nc` (number of classes) to 1, specifically for shrimp fry detection.
# - Adjusting the `n` scale parameters to `[0.67, 0.33, 1024]` to potentially improve small object detection.
# - Increasing the `repeats` parameter in all `C3k2` modules within both the `backbone` and `head` sections from 2 to 3, enhancing the model's capacity to learn more complex features.
#
# **Reasoning for modifications:**
#
# 1.  **`nc: 1` (number of classes):** The original model was configured for 80 classes. By setting `nc` to 1, the model is specialized to detect only "shrimp fry," reducing complexity and improving focus for this specific task.
#
# 2.  **`n: [0.67, 0.33, 1024]` (scale parameters for depth and width):**
#     *   **Depth (`0.67` from `0.50`):** A deeper network can learn more intricate representations, which is beneficial for detecting small objects with subtle features like shrimp fry.
#     *   **Width (`0.33` from `0.25`):** More channels allow the network to process more information at each layer, helping to capture fine-grained details of small objects.
#
# 3.  **Increasing `repeats` in `C3k2` modules (from 2 to 3):** `C3k2` modules are crucial for feature extraction. Increasing their repeats makes these blocks deeper and more powerful, allowing the model to learn more robust and discriminative features, which is essential for accurate identification and localization of small objects.

# %%
from ultralytics import YOLO
import torch

# %%
if torch.cuda.is_available():
    device = torch.device("cuda:0") # Use the first GPU
    print(f"Training on GPU: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu")
    print("CUDA not available. Training on CPU.")
# Out:
# Training on GPU: NVIDIA GeForce RTX 2060 SUPER

# %%
# !wandb login 32d59652dce5721c31255007b9c572f3010acf97
# Out:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\Ery\_netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin

# %%
# !wandb login 32d59652dce5721c31255007b9c572f3010acf97
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\Ery\_netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin

# %%
torch.cuda.empty_cache()

# %%
model = YOLO('yolo11shrimp.yaml') 

result = model.train(
    data='Shrimp-larvae-detection-1/data.yaml',
    epochs = 60,
    batch = 20,
    device=0
)
# Out:
# Ultralytics 8.3.203  Python-3.13.7 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2060 SUPER, 8192MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=20, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=Shrimp-larvae-detection-1/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=60, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=train4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=E:\PD1ModelTrainings\PD1ModelTrainingCodes\runs\detect\train4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       696  ultralytics.nn.modules.conv.Conv             [3, 24, 3, 2]
#   1                  -1  1     10464  ultralytics.nn.modules.conv.Conv             [24, 48, 3, 2]
#   2                  -1  2     18964  ultralytics.nn.modules.block.C3k2            [48, 88, 2, False, 0.25]
#   3                  -1  1     69872  ultralytics.nn.modules.conv.Conv             [88, 88, 3, 2]
#   4                  -1  2     74360  ultralytics.nn.modules.block.C3k2            [88, 176, 2, False, 0.25]
#   5                  -1  1    279136  ultralytics.nn.modules.conv.Conv             [176, 176, 3, 2]
#   6                  -1  2    265408  ultralytics.nn.modules.block.C3k2            [176, 176, 2, True]
#   7                  -1  1    545584  ultralytics.nn.modules.conv.Conv             [176, 344, 3, 2]
#   8                  -1  2   1009984  ultralytics.nn.modules.block.C3k2            [344, 344, 2, True]
#   9                  -1  1    296872  ultralytics.nn.modules.block.SPPF            [344, 344, 5]
#  10                  -1  1    449092  ultralytics.nn.modules.block.C2PSA           [344, 344, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2    294096  ultralytics.nn.modules.block.C3k2            [520, 176, 2, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2     81928  ultralytics.nn.modules.block.C3k2            [352, 88, 2, False]
#  17                  -1  1     69872  ultralytics.nn.modules.conv.Conv             [88, 88, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2    249040  ultralytics.nn.modules.block.C3k2            [264, 176, 2, False]
#  20                  -1  1    279136  ultralytics.nn.modules.conv.Conv             [176, 176, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   1070528  ultralytics.nn.modules.block.C3k2            [520, 344, 2, True]
#  23        [16, 19, 22]  1    561715  ultralytics.nn.modules.head.Detect           [1, [88, 176, 344]]
# YOLO11n summary: 243 layers, 5,626,747 parameters, 5,626,731 gradients, 13.4 GFLOPs
#
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.20.1 ms, read: 70.873.1 MB/s, size: 35.1 KB)
# train: Scanning E:\PD1ModelTrainings\PD1ModelTrainingCodes\Shrimp-larvae-detection-1\train\labels.cache... 4140 images, 35 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4140/4140 4.8Mit/s 0.0s0s
# WARNING Box and segment counts should be equal, but got len(segments) = 4397, len(boxes) = 143573. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access  (ping: 0.40.1 ms, read: 29.114.7 MB/s, size: 23.9 KB)
# val: Scanning E:\PD1ModelTrainings\PD1ModelTrainingCodes\Shrimp-larvae-detection-1\valid\labels.cache... 386 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 386/386 337.0Kit/s 0.0s
# WARNING Box and segment counts should be equal, but got len(segments) = 407, len(boxes) = 13790. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to E:\PD1ModelTrainings\PD1ModelTrainingCodes\runs\detect\train4\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 112 weight(decay=0.0), 119 weight(decay=0.00046875), 118 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to E:\PD1ModelTrainings\PD1ModelTrainingCodes\runs\detect\train4
# Starting training for 60 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/60       6.8G       3.28      2.534      2.273        841        640: 100% ━━━━━━━━━━━━ 207/207 2.6it/s 1:21<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.0it/s 5.0s.5ss
#                    all        386      13790      0.598      0.659      0.562      0.185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/60      7.17G      1.884      1.112      1.162        883        640: 100% ━━━━━━━━━━━━ 207/207 2.4it/s 1:28<0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.1it/s 4.7s.5ss
#                    all        386      13790      0.725      0.798      0.708      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/60      7.86G      1.796      1.067      1.107       1051        640: 100% ━━━━━━━━━━━━ 207/207 2.3it/s 1:28<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790      0.725      0.796      0.726      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/60      9.72G      1.716      1.012      1.081        761        640: 100% ━━━━━━━━━━━━ 207/207 0.5it/s 7:34<3.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 1.3it/s 7.8s.5ss
#                    all        386      13790      0.723      0.745      0.668      0.284
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/60      7.43G      1.674       0.99      1.061        701        640: 100% ━━━━━━━━━━━━ 207/207 2.8it/s 1:15<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.1it/s 4.7s.5ss
#                    all        386      13790      0.757      0.795      0.723      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/60      5.91G      1.634     0.9592      1.042        811        640: 100% ━━━━━━━━━━━━ 207/207 2.9it/s 1:11<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.1it/s 4.8s.5ss
#                    all        386      13790      0.843      0.875      0.882      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/60      7.04G      1.596     0.9395      1.031       1148        640: 100% ━━━━━━━━━━━━ 207/207 2.9it/s 1:12<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790      0.816      0.851      0.842      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/60      8.28G      1.578     0.9206      1.027        876        640: 100% ━━━━━━━━━━━━ 207/207 2.5it/s 1:21<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.1it/s 4.7s.5ss
#                    all        386      13790      0.836       0.87       0.86      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/60      8.95G      1.565     0.9109      1.024       1074        640: 100% ━━━━━━━━━━━━ 207/207 2.0it/s 1:44<1.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790      0.713      0.737      0.661      0.248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/60      7.74G      1.555     0.9078       1.02       1105        640: 100% ━━━━━━━━━━━━ 207/207 2.3it/s 1:29<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790      0.702      0.744      0.671      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/60      7.71G      1.532     0.8862      1.009        568        640: 100% ━━━━━━━━━━━━ 207/207 2.4it/s 1:25<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.1it/s 4.7s.5ss
#                    all        386      13790      0.845      0.863      0.885      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/60      7.69G      1.521     0.8786       1.01        992        640: 100% ━━━━━━━━━━━━ 207/207 2.1it/s 1:40<0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790      0.812      0.842      0.837      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/60      8.85G      1.513     0.8845      1.005        768        640: 100% ━━━━━━━━━━━━ 207/207 1.2it/s 2:51<2.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790      0.849      0.871      0.896      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/60      9.33G      1.508     0.8707      1.009       1182        640: 100% ━━━━━━━━━━━━ 207/207 1.9it/s 1:51<0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.1it/s 4.7s.5ss
#                    all        386      13790       0.84      0.883      0.896      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/60
640: 100% ━━━━━━━━━━━━ 207/207 2.9it/s 1:11<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790      0.878      0.918      0.947      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/60      6.38G      1.288     0.6918      0.946        627        640: 100% ━━━━━━━━━━━━ 207/207 2.9it/s 1:12<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790      0.874      0.919      0.942       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/60      9.02G      1.274     0.6838     0.9451        705        640: 100% ━━━━━━━━━━━━ 207/207 1.5it/s 2:14<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790      0.878      0.914      0.945      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/60      8.72G      1.266     0.6736     0.9416       1079        640: 100% ━━━━━━━━━━━━ 207/207 0.5it/s 7:02<2.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.5s.5ss
#                    all        386      13790      0.878      0.909      0.944      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/60      8.43G      1.271     0.6808      0.943        833        640: 100% ━━━━━━━━━━━━ 207/207 2.6it/s 1:18<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790      0.882      0.906      0.942      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/60      7.96G      1.275     0.6782     0.9427       1382        640: 100% ━━━━━━━━━━━━ 207/207 2.7it/s 1:16<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.1it/s 4.8s.5ss
#                    all        386      13790      0.879      0.919      0.947       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/60      7.87G      1.254     0.6665     0.9336       1079        640: 100% ━━━━━━━━━━━━ 207/207 2.4it/s 1:26<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790       0.88      0.919      0.946      0.619
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/60      6.51G      1.259     0.6703     0.9556        507        640: 100% ━━━━━━━━━━━━ 207/207 3.0it/s 1:09<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.1it/s 4.7s.5ss
#                    all        386      13790      0.877      0.912      0.941      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/60      6.59G      1.244     0.6624     0.9555        451        640: 100% ━━━━━━━━━━━━ 207/207 3.0it/s 1:09<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790      0.879      0.918      0.946      0.607
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/60      7.23G      1.231     0.6575     0.9514        490        640: 100% ━━━━━━━━━━━━ 207/207 2.7it/s 1:16<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790      0.882      0.917      0.949      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/60      6.96G      1.216     0.6486     0.9449        710        640: 100% ━━━━━━━━━━━━ 207/207 3.0it/s 1:10<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790      0.882      0.921      0.949      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/60      6.41G      1.221     0.6483     0.9504        582        640: 100% ━━━━━━━━━━━━ 207/207 3.0it/s 1:09<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790       0.88      0.923      0.949      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/60      6.16G       1.21     0.6434     0.9453        869        640: 100% ━━━━━━━━━━━━ 207/207 3.0it/s 1:10<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790      0.883      0.922       0.95      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/60      6.27G       1.21     0.6427     0.9476        388        640: 100% ━━━━━━━━━━━━ 207/207 3.0it/s 1:09<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790       0.88      0.921       0.95      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/60       7.3G      1.194     0.6343     0.9418        541        640: 100% ━━━━━━━━━━━━ 207/207 2.9it/s 1:12<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790      0.881      0.924       0.95      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/60      7.28G      1.196     0.6314     0.9405        565        640: 100% ━━━━━━━━━━━━ 207/207 3.0it/s 1:09<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790      0.887      0.924      0.954      0.642
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/60      5.88G      1.196     0.6338     0.9423        621        640: 100% ━━━━━━━━━━━━ 207/207 3.0it/s 1:09<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s.5ss
#                    all        386      13790       0.89      0.921      0.954      0.636
#
# 60 epochs completed in 1.816 hours.
# Optimizer stripped from E:\PD1ModelTrainings\PD1ModelTrainingCodes\runs\detect\train4\weights\last.pt, 11.6MB
# Optimizer stripped from E:\PD1ModelTrainings\PD1ModelTrainingCodes\runs\detect\train4\weights\best.pt, 11.6MB
#
# Validating E:\PD1ModelTrainings\PD1ModelTrainingCodes\runs\detect\train4\weights\best.pt...
# Ultralytics 8.3.203  Python-3.13.7 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2060 SUPER, 8192MiB)
# YOLO11n summary (fused): 131 layers, 5,614,293 parameters, 0 gradients, 13.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 1.8it/s 5.6s.5ss
#                    all        386      13790      0.887      0.924      0.954      0.642
# Speed: 0.2ms preprocess, 4.9ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to E:\PD1ModelTrainings\PD1ModelTrainingCodes\runs\detect\train4

# %%
model_test = YOLO('YOLO.pt')

# %%
test_pred = model_test.predict(source="test.jpg",show_labels=False,show_conf=False,save=True)
# Out:
# image 1/1 e:\PD1ModelTrainings\PD1ModelTrainingCodes\test.jpg: 448x640 295 s, 55.8ms
# Speed: 3.7ms preprocess, 55.8ms inference, 50.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to E:\PD1ModelTrainings\PD1ModelTrainingCodes\runs\detect\predict2
